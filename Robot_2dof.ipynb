# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyNguyen001/BaiTapAI/blob/main/Robot_2dof.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Activation, Dropout, BatchNormalization, LSTM
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
import csv
import math as m
l1 = 50
l2 = 40
with open('/content/Robot_2dof.csv','w') as file:
  writer = csv.writer(file)
  writer.writerow(['tt1','tt2','Px','Py'])

  for tt1 in range(-180,180,1):
    for tt2 in range(-180,180,1):
      tt1 = (tt1*m.pi)/180
      tt2 = (tt2*m.pi)/180
      Px = l1*m.cos(tt1) + l2*m.cos(tt1+tt2)
      Py = l1*m.sin(tt1) + l2*m.sin(tt1+tt2)
      writer.writerow([tt1,tt2,Px,Py])

# %%
data=pd.read_csv('/content/Robot_2dof.csv')
data
# Out:
#                  tt1       tt2         Px            Py
# 0      -3.141593e+00 -3.141593 -10.000000  3.673940e-15
# 1      -5.483114e-02 -3.124139   9.952796 -1.245418e+00
# 2      -9.569838e-04 -3.106686  10.023026 -1.405572e+00
# 3      -1.670252e-05 -3.089233  10.054784 -2.093606e+00
# 4      -2.915140e-07 -3.071779  10.097437 -2.790262e+00
# ...              ...       ...        ...           ...
# 129595  0.000000e+00  3.054326  10.152212  3.486230e+00
# 129596  0.000000e+00  3.071779  10.097438  2.790259e+00
# 129597  0.000000e+00  3.089233  10.054819  2.093438e+00
# 129598  0.000000e+00  3.106686  10.024367  1.395980e+00
# 129599  0.000000e+00  3.124139  10.006092  6.980963e-01
#
# [129600 rows x 4 columns]

# %%
x=data.drop(data.columns[:2],axis=1)
x
# Out:
#                Px            Py
# 0      -10.000000  3.673940e-15
# 1        9.952796 -1.245418e+00
# 2       10.023026 -1.405572e+00
# 3       10.054784 -2.093606e+00
# 4       10.097437 -2.790262e+00
# ...           ...           ...
# 129595  10.152212  3.486230e+00
# 129596  10.097438  2.790259e+00
# 129597  10.054819  2.093438e+00
# 129598  10.024367  1.395980e+00
# 129599  10.006092  6.980963e-01
#
# [129600 rows x 2 columns]

# %%
y=data.drop(data.columns[2:],axis=1)
y
# Out:
#                  tt1       tt2
# 0      -3.141593e+00 -3.141593
# 1      -5.483114e-02 -3.124139
# 2      -9.569838e-04 -3.106686
# 3      -1.670252e-05 -3.089233
# 4      -2.915140e-07 -3.071779
# ...              ...       ...
# 129595  0.000000e+00  3.054326
# 129596  0.000000e+00  3.071779
# 129597  0.000000e+00  3.089233
# 129598  0.000000e+00  3.106686
# 129599  0.000000e+00  3.124139
#
# [129600 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=10)

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout 
model=Sequential()
model.add(Dense(512,activation='relu',input_shape=(2,)))
model.add(Dense(100,activation='relu'))
model.add(Dense(50,activation='relu'))
model.add(Dense(2,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1536
#
#  dense_1 (Dense)             (None, 100)               51300
#
#  dense_2 (Dense)             (None, 50)                5050
#
#  dense_3 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 57,988
# Trainable params: 57,988
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping
model.compile(loss='mse',optimizer=RMSprop(),metrics=['accuracy'])
history = model.fit(x_train,y_train,batch_size = 128,epochs=500,verbose=1,callbacks=[EarlyStopping(monitor='val_loss',patience=20)],validation_data = (x_test, y_test))
# Out:
# Epoch 1/500
# 760/760 [==============================] - 8s 7ms/step - loss: 1.3734 - accuracy: 0.9864 - val_loss: 1.3815 - val_accuracy: 0.9806
# Epoch 2/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3718 - accuracy: 0.9902 - val_loss: 1.3748 - val_accuracy: 0.9936
# Epoch 3/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3710 - accuracy: 0.9866 - val_loss: 1.3747 - val_accuracy: 0.9907
# Epoch 4/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3710 - accuracy: 0.9854 - val_loss: 1.3748 - val_accuracy: 0.9965
# Epoch 5/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3697 - accuracy: 0.9902 - val_loss: 1.3751 - val_accuracy: 0.9906
# Epoch 6/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3701 - accuracy: 0.9931 - val_loss: 1.3751 - val_accuracy: 0.9906
# Epoch 7/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3709 - accuracy: 0.9944 - val_loss: 1.3747 - val_accuracy: 0.9996
# Epoch 8/500
# 760/760 [==============================] - 4s 6ms/step - loss: 1.3689 - accuracy: 0.9945 - val_loss: 1.3744 - val_accuracy: 0.9966
# Epoch 9/500
# 760/760 [==============================] - 4s 6ms/step - loss: 1.3709 - accuracy: 0.9934 - val_loss: 1.3748 - val_accuracy: 0.9996
# Epoch 10/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3701 - accuracy: 0.9950 - val_loss: 1.3747 - val_accuracy: 0.9965
# Epoch 11/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3697 - accuracy: 0.9959 - val_loss: 1.3744 - val_accuracy: 0.9997
# Epoch 12/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3700 - accuracy: 0.9956 - val_loss: 1.3744 - val_accuracy: 0.9997
# Epoch 13/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3696 - accuracy: 0.9944 - val_loss: 1.3748 - val_accuracy: 0.9917
# Epoch 14/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3719 - accuracy: 0.9887 - val_loss: 1.3748 - val_accuracy: 0.9907
# Epoch 15/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3728 - accuracy: 0.9863 - val_loss: 1.3747 - val_accuracy: 0.9907
# Epoch 16/500
# 760/760 [==============================] - 3s 5ms/step - loss: 1.3701 - accuracy: 0.9947 - val_loss: 1.3747 - val_accuracy: 0.9918
# Epoch 17/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3703 - accuracy: 0.9914 - val_loss: 1.3752 - val_accuracy: 0.9883
# Epoch 18/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3691 - accuracy: 0.9952 - val_loss: 1.3746 - val_accuracy: 0.9907
# Epoch 19/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3695 - accuracy: 0.9935 - val_loss: 1.3745 - val_accuracy: 0.9996
# Epoch 20/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3783 - accuracy: 0.9741 - val_loss: 1.3880 - val_accuracy: 0.9610
# Epoch 21/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3808 - accuracy: 0.9663 - val_loss: 1.3876 - val_accuracy: 0.9638
# Epoch 22/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3817 - accuracy: 0.9634 - val_loss: 1.3873 - val_accuracy: 0.9639
# Epoch 23/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3818 - accuracy: 0.9636 - val_loss: 1.3870 - val_accuracy: 0.9665
# Epoch 24/500
# 760/760 [==============================] - 3s 5ms/step - loss: 1.3824 - accuracy: 0.9644 - val_loss: 1.3865 - val_accuracy: 0.9694
# Epoch 25/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3808 - accuracy: 0.9681 - val_loss: 1.3868 - val_accuracy: 0.9666
# Epoch 26/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3755 - accuracy: 0.9840 - val_loss: 1.3747 - val_accuracy: 0.9944
# Epoch 27/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3700 - accuracy: 0.9934 - val_loss: 1.3745 - val_accuracy: 0.9969
# Epoch 28/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3709 - accuracy: 0.9948 - val_loss: 1.3746 - val_accuracy: 0.9996
# Epoch 29/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3695 - accuracy: 0.9932 - val_loss: 1.3744 - val_accuracy: 0.9937
# Epoch 30/500
# 760/760 [==============================] - 4s 6ms/step - loss: 1.3706 - accuracy: 0.9923 - val_loss: 1.3747 - val_accuracy: 0.9907
# Epoch 31/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3704 - accuracy: 0.9919 - val_loss: 1.3745 - val_accuracy: 0.9937
# Epoch 32/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3692 - accuracy: 0.9933 - val_loss: 1.3744 - val_accuracy: 0.9918
# Epoch 33/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3699 - accuracy: 0.9952 - val_loss: 1.3743 - val_accuracy: 0.9970
# Epoch 34/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3698 - accuracy: 0.9956 - val_loss: 1.3746 - val_accuracy: 0.9969
# Epoch 35/500
# 760/760 [==============================] - 3s 5ms/step - loss: 1.3692 - accuracy: 0.9901 - val_loss: 1.3745 - val_accuracy: 0.9907
# Epoch 36/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3694 - accuracy: 0.9924 - val_loss: 1.3746 - val_accuracy: 0.9936
# Epoch 37/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3708 - accuracy: 0.9958 - val_loss: 1.3746 - val_accuracy: 0.9944
# Epoch 38/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3707 - accuracy: 0.9943 - val_loss: 1.3745 - val_accuracy: 0.9944
# Epoch 39/500
# 760/760 [==============================] - 3s 5ms/step - loss: 1.3707 - accuracy: 0.9950 - val_loss: 1.3745 - val_accuracy: 0.9969
# Epoch 40/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3694 - accuracy: 0.9945 - val_loss: 1.3747 - val_accuracy: 0.9944
# Epoch 41/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3692 - accuracy: 0.9942 - val_loss: 1.3742 - val_accuracy: 0.9945
# Epoch 42/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3695 - accuracy: 0.9942 - val_loss: 1.3743 - val_accuracy: 0.9944
# Epoch 43/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3691 - accuracy: 0.9951 - val_loss: 1.3744 - val_accuracy: 0.9944
# Epoch 44/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3701 - accuracy: 0.9925 - val_loss: 1.3846 - val_accuracy: 0.9806
# Epoch 45/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3706 - accuracy: 0.9908 - val_loss: 1.3747 - val_accuracy: 0.9944
# Epoch 46/500
# 760/760 [==============================] - 3s 5ms/step - loss: 1.3695 - accuracy: 0.9898 - val_loss: 1.3748 - val_accuracy: 0.9884
# Epoch 47/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3689 - accuracy: 0.9923 - val_loss: 1.3739 - val_accuracy: 0.9938
# Epoch 48/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3691 - accuracy: 0.9947 - val_loss: 1.3739 - val_accuracy: 0.9967
# Epoch 49/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3687 - accuracy: 0.9942 - val_loss: 1.3744 - val_accuracy: 0.9937
# Epoch 50/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3692 - accuracy: 0.9953 - val_loss: 1.3744 - val_accuracy: 0.9966
# Epoch 51/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3706 - accuracy: 0.9971 - val_loss: 1.3747 - val_accuracy: 0.9918
# Epoch 52/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3704 - accuracy: 0.9921 - val_loss: 1.3740 - val_accuracy: 0.9945
# Epoch 53/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3693 - accuracy: 0.9968 - val_loss: 1.3743 - val_accuracy: 0.9966
# Epoch 54/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3694 - accuracy: 0.9935 - val_loss: 1.3841 - val_accuracy: 0.9808
# Epoch 55/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3770 - accuracy: 0.9798 - val_loss: 1.3852 - val_accuracy: 0.9725
# Epoch 56/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3828 - accuracy: 0.9704 - val_loss: 1.3852 - val_accuracy: 0.9725
# Epoch 57/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3813 - accuracy: 0.9724 - val_loss: 1.3844 - val_accuracy: 0.9784
# Epoch 58/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3816 - accuracy: 0.9700 - val_loss: 1.3861 - val_accuracy: 0.9695
# Epoch 59/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3817 - accuracy: 0.9632 - val_loss: 1.3861 - val_accuracy: 0.9667
# Epoch 60/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3807 - accuracy: 0.9708 - val_loss: 1.3864 - val_accuracy: 0.9694
# Epoch 61/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3805 - accuracy: 0.9664 - val_loss: 1.3884 - val_accuracy: 0.9609
# Epoch 62/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3825 - accuracy: 0.9631 - val_loss: 1.3862 - val_accuracy: 0.9667
# Epoch 63/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3822 - accuracy: 0.9631 - val_loss: 1.3868 - val_accuracy: 0.9640
# Epoch 64/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3819 - accuracy: 0.9626 - val_loss: 1.3865 - val_accuracy: 0.9666
# Epoch 65/500
# 760/760 [==============================] - 4s 5ms/step - loss: 1.3814 - accuracy: 0.9644 - val_loss: 1.3860 - val_accuracy: 0.9668
# Epoch 66/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3806 - accuracy: 0.9674 - val_loss: 1.3854 - val_accuracy: 0.9697
# Epoch 67/500
# 760/760 [==============================] - 3s 4ms/step - loss: 1.3806 - accuracy: 0.9670 - val_loss: 1.3864 - val_accuracy: 0.9641

# %%
score=model.evaluate(x_test,y_test,verbose=0)
print('Sai số: ',score[0])
print('Độ chính xác: ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('Epochs')
plt.legend(['train','Validation'])
plt.show()
# Out:
# Sai số:  1.386425495147705
# Độ chính xác:  0.964104950428009

# %%
model.save('model_Robot_2dof.h5')
