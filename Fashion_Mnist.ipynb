# %% [markdown]
# <a href="https://colab.research.google.com/github/TonyNguyen001/BaiTapAI/blob/main/Fashion_Mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import thư viện
import numpy as np #thư viện xử lý ma trận
from keras.utils import np_utils # thư viện xử lý chuyển class
from keras.datasets import fashion_mnist # gọi tập dataset thời trang
from keras.models import Sequential # hàm chạy mô hình
from keras.layers import Dense, Dropout # tạo mạng nơ ron
from tensorflow.keras.optimizers import RMSprop 
import matplotlib.pyplot as plt  # thư viện dùng để vẽ

# %%
# chia tập dữ liệu thành 2 bộ train và test
(x_train, y_train),(x_test,y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# xem kích thược của tập dữ liệu
print('Kích thước x_train: ', x_train.shape)
print('Kích thước y_train: ', y_train.shape)
print('Kích thước x_test: ', x_test.shape)
print('Kích thước y_test: ', y_test.shape)
# Out:
# Kích thước x_train:  (60000, 28, 28)
# Kích thước y_train:  (60000,)
# Kích thước x_test:  (10000, 28, 28)
# Kích thước y_test:  (10000,)

# %%
#chuyển chiều của x từ 3 chiều về 2 chiều
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
# ép kiểu
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
#chuẩn hóa dữ liệu
x_train /=255
x_test /=255
#chuyển y từ 1 class thành 10 class
y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)

# %%
#tạo mạng nơ-ron
model = Sequential()
model.add(Dense(512,activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
#chạy model với số lần học là 500 và độ kiên nhẫn là 100
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(), metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(), metrics=['accuracy'])
from keras.callbacks import EarlyStopping
history = model.fit(x_train,y_train,batch_size=128,epochs=500,verbose=1,
                    validation_split=0.2,callbacks=[EarlyStopping(monitor='val_loss',patience=100)])
# Out:
# Epoch 1/500
# 375/375 [==============================] - 9s 23ms/step - loss: 0.5931 - accuracy: 0.7846 - val_loss: 0.4245 - val_accuracy: 0.8464
# Epoch 2/500
# 375/375 [==============================] - 9s 23ms/step - loss: 0.4157 - accuracy: 0.8469 - val_loss: 0.3925 - val_accuracy: 0.8566
# Epoch 3/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3758 - accuracy: 0.8607 - val_loss: 0.3699 - val_accuracy: 0.8682
# Epoch 4/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3536 - accuracy: 0.8723 - val_loss: 0.3402 - val_accuracy: 0.8804
# Epoch 5/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3393 - accuracy: 0.8776 - val_loss: 0.3495 - val_accuracy: 0.8792
# Epoch 6/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3273 - accuracy: 0.8820 - val_loss: 0.3573 - val_accuracy: 0.8770
# Epoch 7/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3214 - accuracy: 0.8842 - val_loss: 0.3602 - val_accuracy: 0.8823
# Epoch 8/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3156 - accuracy: 0.8867 - val_loss: 0.3408 - val_accuracy: 0.8832
# Epoch 9/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.3100 - accuracy: 0.8882 - val_loss: 0.3521 - val_accuracy: 0.8839
# Epoch 10/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2961 - accuracy: 0.8929 - val_loss: 0.3602 - val_accuracy: 0.8756
# Epoch 11/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2923 - accuracy: 0.8946 - val_loss: 0.3526 - val_accuracy: 0.8878
# Epoch 12/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2889 - accuracy: 0.8966 - val_loss: 0.3482 - val_accuracy: 0.8879
# Epoch 13/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2822 - accuracy: 0.8981 - val_loss: 0.3649 - val_accuracy: 0.8898
# Epoch 14/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2831 - accuracy: 0.8993 - val_loss: 0.3642 - val_accuracy: 0.8873
# Epoch 15/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2794 - accuracy: 0.9011 - val_loss: 0.3610 - val_accuracy: 0.8961
# Epoch 16/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2743 - accuracy: 0.9036 - val_loss: 0.3700 - val_accuracy: 0.8908
# Epoch 17/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2675 - accuracy: 0.9034 - val_loss: 0.3776 - val_accuracy: 0.8872
# Epoch 18/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2674 - accuracy: 0.9040 - val_loss: 0.3690 - val_accuracy: 0.8919
# Epoch 19/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2646 - accuracy: 0.9076 - val_loss: 0.3935 - val_accuracy: 0.8887
# Epoch 20/500
# 375/375 [==============================] - 6s 17ms/step - loss: 0.2613 - accuracy: 0.9079 - val_loss: 0.3975 - val_accuracy: 0.8928
# Epoch 21/500
# 375/375 [==============================] - 6s 16ms/step - loss: 0.2558 - accuracy: 0.9091 - val_loss: 0.4033 - val_accuracy: 0.8931
# Epoch 22/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2557 - accuracy: 0.9086 - val_loss: 0.4064 - val_accuracy: 0.8896
# Epoch 23/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2511 - accuracy: 0.9090 - val_loss: 0.4555 - val_accuracy: 0.8926
# Epoch 24/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2524 - accuracy: 0.9118 - val_loss: 0.3894 - val_accuracy: 0.8947
# Epoch 25/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2550 - accuracy: 0.9120 - val_loss: 0.4106 - val_accuracy: 0.8943
# Epoch 26/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2478 - accuracy: 0.9129 - val_loss: 0.4604 - val_accuracy: 0.8784
# Epoch 27/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2481 - accuracy: 0.9136 - val_loss: 0.4446 - val_accuracy: 0.8911
# Epoch 28/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2441 - accuracy: 0.9152 - val_loss: 0.4307 - val_accuracy: 0.8889
# Epoch 29/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2419 - accuracy: 0.9157 - val_loss: 0.4529 - val_accuracy: 0.8896
# Epoch 30/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2372 - accuracy: 0.9163 - val_loss: 0.4275 - val_accuracy: 0.8959
# Epoch 31/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2357 - accuracy: 0.9179 - val_loss: 0.4566 - val_accuracy: 0.8894
# Epoch 32/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2360 - accuracy: 0.9168 - val_loss: 0.4624 - val_accuracy: 0.8936
# Epoch 33/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2368 - accuracy: 0.9191 - val_loss: 0.4594 - val_accuracy: 0.8938
# Epoch 34/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2335 - accuracy: 0.9200 - val_loss: 0.4665 - val_accuracy: 0.8938
# Epoch 35/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2296 - accuracy: 0.9191 - val_loss: 0.4881 - val_accuracy: 0.8950
# Epoch 36/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2308 - accuracy: 0.9212 - val_loss: 0.4713 - val_accuracy: 0.8963
# Epoch 37/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2250 - accuracy: 0.9209 - val_loss: 0.5038 - val_accuracy: 0.8957
# Epoch 38/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2222 - accuracy: 0.9221 - val_loss: 0.4856 - val_accuracy: 0.8966
# Epoch 39/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2261 - accuracy: 0.9219 - val_loss: 0.5188 - val_accuracy: 0.8868
# Epoch 40/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2232 - accuracy: 0.9225 - val_loss: 0.5627 - val_accuracy: 0.8894
# Epoch 41/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.2227 - accuracy: 0.9246 - val_loss: 0.5046 - val_accuracy: 0.8982
# Epoch 42/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2240 - accuracy: 0.9253 - val_loss: 0.5093 - val_accuracy: 0.8946
# Epoch 43/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.2218 - accuracy: 0.9249 - val_loss: 0.5070 - val_accuracy: 0.8928
# Epoch 44/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2178 - accuracy: 0.9255 - val_loss: 0.5598 - val_accuracy: 0.8917
# Epoch 45/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2239 - accuracy: 0.9254 - val_loss: 0.5578 - val_accuracy: 0.8938
# Epoch 46/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2146 - accuracy: 0.9255 - val_loss: 0.5484 - val_accuracy: 0.8954
# Epoch 47/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2119 - accuracy: 0.9282 - val_loss: 0.6330 - val_accuracy: 0.8894
# Epoch 48/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2180 - accuracy: 0.9254 - val_loss: 0.5412 - val_accuracy: 0.8938
# Epoch 49/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2102 - accuracy: 0.9291 - val_loss: 0.6001 - val_accuracy: 0.8983
# Epoch 50/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2112 - accuracy: 0.9293 - val_loss: 0.5383 - val_accuracy: 0.8910
# Epoch 51/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2111 - accuracy: 0.9291 - val_loss: 0.6238 - val_accuracy: 0.8943
# Epoch 52/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.2070 - accuracy: 0.9285 - val_loss: 0.6091 - val_accuracy: 0.8902
# Epoch 53/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2096 - accuracy: 0.9283 - val_loss: 0.5842 - val_accuracy: 0.9007
# Epoch 54/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2074 - accuracy: 0.9300 - val_loss: 0.5668 - val_accuracy: 0.8921
# Epoch 55/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2072 - accuracy: 0.9310 - val_loss: 0.6272 - val_accuracy: 0.8938
# Epoch 56/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2030 - accuracy: 0.9309 - val_loss: 0.6450 - val_accuracy: 0.8931
# Epoch 57/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1966 - accuracy: 0.9324 - val_loss: 0.6473 - val_accuracy: 0.8948
# Epoch 58/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2075 - accuracy: 0.9315 - val_loss: 0.6336 - val_accuracy: 0.8938
# Epoch 59/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1989 - accuracy: 0.9319 - val_loss: 0.5991 - val_accuracy: 0.8949
# Epoch 60/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2040 - accuracy: 0.9320 - val_loss: 0.6753 - val_accuracy: 0.8918
# Epoch 61/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.2005 - accuracy: 0.9327 - val_loss: 0.6197 - val_accuracy: 0.8951
# Epoch 62/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1977 - accuracy: 0.9336 - val_loss: 0.7040 - val_accuracy: 0.8947
# Epoch 63/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1981 - accuracy: 0.9330 - val_loss: 0.6943 - val_accuracy: 0.8942
# Epoch 64/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1963 - accuracy: 0.9343 - val_loss: 0.6805 - val_accuracy: 0.8909
# Epoch 65/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1966 - accuracy: 0.9356 - val_loss: 0.6698 - val_accuracy: 0.8923
# Epoch 66/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1932 - accuracy: 0.9345 - val_loss: 0.6754 - val_accuracy: 0.8917
# Epoch 67/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1960 - accuracy: 0.9363 - val_loss: 0.7360 - val_accuracy: 0.8966
# Epoch 68/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.2000 - accuracy: 0.9365 - val_loss: 0.7339 - val_accuracy: 0.8926
# Epoch 69/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1915 - accuracy: 0.9353 - val_loss: 0.7577 - val_accuracy: 0.8908
# Epoch 70/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1953 - accuracy: 0.9371 - val_loss: 0.7459 - val_accuracy: 0.8938
# Epoch 71/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1968 - accuracy: 0.9355 - val_loss: 0.7817 - val_accuracy: 0.8974
# Epoch 72/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1960 - accuracy: 0.9370 - val_loss: 0.8551 - val_accuracy: 0.8904
# Epoch 73/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1971 - accuracy: 0.9376 - val_loss: 0.7046 - val_accuracy: 0.8915
# Epoch 74/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1955 - accuracy: 0.9361 - val_loss: 0.7891 - val_accuracy: 0.8957
# Epoch 75/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1861 - accuracy: 0.9397 - val_loss: 0.8080 - val_accuracy: 0.8885
# Epoch 76/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1854 - accuracy: 0.9401 - val_loss: 0.7465 - val_accuracy: 0.8952
# Epoch 77/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1959 - accuracy: 0.9359 - val_loss: 0.7987 - val_accuracy: 0.8932
# Epoch 78/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1893 - accuracy: 0.9392 - val_loss: 0.7417 - val_accuracy: 0.8971
# Epoch 79/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1853 - accuracy: 0.9401 - val_loss: 0.7863 - val_accuracy: 0.8938
# Epoch 80/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1883 - accuracy: 0.9389 - val_loss: 0.8187 - val_accuracy: 0.8957
# Epoch 81/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1835 - accuracy: 0.9396 - val_loss: 0.8948 - val_accuracy: 0.8942
# Epoch 82/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1873 - accuracy: 0.9400 - val_loss: 0.7521 - val_accuracy: 0.8925
# Epoch 83/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1788 - accuracy: 0.9406 - val_loss: 0.8862 - val_accuracy: 0.8905
# Epoch 84/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1831 - accuracy: 0.9401 - val_loss: 0.9446 - val_accuracy: 0.8964
# Epoch 85/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1806 - accuracy: 0.9403 - val_loss: 0.8488 - val_accuracy: 0.8933
# Epoch 86/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1869 - accuracy: 0.9398 - val_loss: 0.7970 - val_accuracy: 0.8983
# Epoch 87/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1780 - accuracy: 0.9430 - val_loss: 0.7671 - val_accuracy: 0.8953
# Epoch 88/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1848 - accuracy: 0.9415 - val_loss: 0.8755 - val_accuracy: 0.8967
# Epoch 89/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1825 - accuracy: 0.9415 - val_loss: 0.8055 - val_accuracy: 0.8926
# Epoch 90/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1769 - accuracy: 0.9423 - val_loss: 0.8694 - val_accuracy: 0.8918
# Epoch 91/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1749 - accuracy: 0.9431 - val_loss: 0.8539 - val_accuracy: 0.8947
# Epoch 92/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1806 - accuracy: 0.9426 - val_loss: 0.8140 - val_accuracy: 0.8926
# Epoch 93/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1779 - accuracy: 0.9441 - val_loss: 0.8326 - val_accuracy: 0.8906
# Epoch 94/500
# 375/375 [==============================] - 5s 14ms/step - loss: 0.1766 - accuracy: 0.9440 - val_loss: 0.8900 - val_accuracy: 0.8975
# Epoch 95/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1728 - accuracy: 0.9441 - val_loss: 0.8241 - val_accuracy: 0.8947
# Epoch 96/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1732 - accuracy: 0.9444 - val_loss: 0.8871 - val_accuracy: 0.8982
# Epoch 97/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1785 - accuracy: 0.9444 - val_loss: 0.8782 - val_accuracy: 0.8954
# Epoch 98/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1695 - accuracy: 0.9442 - val_loss: 0.9634 - val_accuracy: 0.8913
# Epoch 99/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1796 - accuracy: 0.9429 - val_loss: 0.8637 - val_accuracy: 0.8942
# Epoch 100/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1740 - accuracy: 0.9450 - val_loss: 0.9178 - val_accuracy: 0.8973
# Epoch 101/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1756 - accuracy: 0.9441 - val_loss: 0.9187 - val_accuracy: 0.8963
# Epoch 102/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1779 - accuracy: 0.9432 - val_loss: 0.8877 - val_accuracy: 0.8896
# Epoch 103/500
# 375/375 [==============================] - 6s 15ms/step - loss: 0.1666 - accuracy: 0.9453 - val_loss: 1.0455 - val_accuracy: 0.8957
# Epoch 104/500
# 375/375 [==============================] - 5s 15ms/step - loss: 0.1742 - accuracy: 0.9444 - val_loss: 0.9679 - val_accuracy: 0.8946

# %%
#đánh giá chất lượng của mô hình và vẽ lại
score = model.evaluate(x_test,y_test,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('Độ chính xác kiểm tra là: ',score[1])
#vẽ đồ thị
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()
# Out:
# Sai số kiểm tra là:  1.1476927995681763
# Độ chính xác kiểm tra là:  0.8894000053405762

# %%
model.save('model_Fashion_Mnist.h5')

# %%
(X_train,y_train),(X_test,y_test) = fashion_mnist.load_data()
for i in range(9):
 plt.subplot(330 + i + 1)
 plt.imshow(X_train[i])
plt.show()
